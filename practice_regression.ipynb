# %%
# !pip install pandas
import pandas as pd
df=pd.read_csv("80_Train.csv",sep=",")
df
# Out:
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.3.0)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.17.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (1.21.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e7c9a8f55d4e> in <module>
#       2 import pandas as pd
#       3 df=pd.read_csv("80_Train.csv",sep=",")
# ----> 4 x_test = x[test]
#       5 y_test = y[test]
#       6 df
#
# NameError: name 'test' is not defined

# %%
x_columns=df.columns
x = df[x_columns].values
y = df['RF'].values

# %%
conda install tensorflow
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.3.0        |              mkl           2 KB  defaults
#     abseil-cpp-20200923.3      |       h2531618_0         919 KB  defaults
#     absl-py-0.13.0             |     pyhd8ed1ab_0          97 KB  conda-forge
#     aiohttp-3.7.4.post0        |   py37h5e8e339_0         625 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     astunparse-1.6.3           |     pyhd8ed1ab_0          15 KB  conda-forge
#     async-timeout-3.0.1        |          py_1000          11 KB  conda-forge
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     cachetools-4.2.2           |     pyhd8ed1ab_0          12 KB  conda-forge
#     certifi-2021.5.30          |   py37h89c1867_0         141 KB  conda-forge
#     click-8.0.1                |   py37h89c1867_0         145 KB  conda-forge
#     dataclasses-0.8            |     pyhc8e2a94_1           7 KB  conda-forge
#     flatbuffers-2.0.0          |       h9c3ff4c_0         1.3 MB  conda-forge
#     gast-0.4.0                 |     pyh9f0ad1d_0          12 KB  conda-forge
#     giflib-5.2.1               |       h36c2ea0_2          77 KB  conda-forge
#     google-auth-1.32.1         |     pyh6c4a22f_0          78 KB  conda-forge
#     google-auth-oauthlib-0.4.1 |             py_2          18 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     grpcio-1.38.1              |   py37hb27c1af_0         2.2 MB  conda-forge
#     h5py-3.3.0                 |nompi_py37ha3df211_100         1.3 MB  conda-forge
#     hdf5-1.10.6                |nompi_h6a2412b_1114         3.1 MB  conda-forge
#     icu-68.1                   |       h58526e2_0        13.0 MB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
#     keras-preprocessing-1.1.2  |     pyhd8ed1ab_0          34 KB  conda-forge
#     libblas-3.9.0              |       9_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |       9_openblas          11 KB  conda-forge
#     libgfortran-ng-9.3.0       |      hff62375_19          22 KB  conda-forge
#     libgfortran5-9.3.0         |      hff62375_19         2.0 MB  conda-forge
#     liblapack-3.9.0            |       9_openblas          11 KB  conda-forge
#     libopenblas-0.3.15         |pthreads_h8fe5266_1         9.2 MB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libprotobuf-3.14.0         |       h780b84a_0         2.5 MB  conda-forge
#     markdown-3.3.4             |     pyhd8ed1ab_0          67 KB  conda-forge
#     multidict-5.1.0            |   py37h5e8e339_1          67 KB  conda-forge
#     numpy-1.21.0               |   py37h038b26d_0         6.1 MB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     opt_einsum-3.3.0           |     pyhd8ed1ab_1          53 KB  conda-forge
#     protobuf-3.14.0            |   py37h2531618_1         303 KB  defaults
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     python-flatbuffers-1.12    |     pyhd3eb1b0_0          24 KB  defaults
#     pyu2f-0.1.5                |     pyhd8ed1ab_0          31 KB  conda-forge
#     requests-oauthlib-1.3.0    |     pyh9f0ad1d_0          21 KB  conda-forge
#     rsa-4.7.2                  |     pyh44b312d_0          28 KB  conda-forge
#     scipy-1.7.0                |   py37h29e03ee_0        21.7 MB  conda-forge
#     snappy-1.1.8               |       he1b5a44_3          32 KB  conda-forge
#     sqlite-3.36.0              |       hc218d9a_0         990 KB  defaults
#     tensorboard-2.5.0          |     pyhd8ed1ab_0         5.5 MB  conda-forge
#     tensorboard-data-server-0.6.0|   py37h7f0c10b_0         3.2 MB  conda-forge
#     tensorboard-plugin-wit-1.8.0|     pyh44b312d_0         670 KB  conda-forge
#     tensorflow-2.5.0           |mkl_py37h3e8b3f4_0           4 KB  defaults
#     tensorflow-base-2.5.0      |mkl_py37h35b2a3d_0        76.6 MB  defaults
#     tensorflow-estimator-2.5.0 |     pyh81a9013_1         289 KB  conda-forge
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     typing-extensions-3.10.0.0 |       hd8ed1ab_0           8 KB  conda-forge
#     typing_extensions-3.10.0.0 |     pyha770c72_0          28 KB  conda-forge
#     werkzeug-2.0.1             |     pyhd8ed1ab_0         219 KB  conda-forge
#     wheel-0.34.2               |           py37_0          43 KB  conda-forge
#     wrapt-1.12.1               |   py37h5e8e339_3          47 KB  conda-forge
#     yarl-1.6.3                 |   py37h5e8e339_2         142 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       155.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _tflow_select      pkgs/main/linux-64::_tflow_select-2.3.0-mkl
#   abseil-cpp         pkgs/main/linux-64::abseil-cpp-20200923.3-h2531618_0
#   absl-py            conda-forge/noarch::absl-py-0.13.0-pyhd8ed1ab_0
#   aiohttp            conda-forge/linux-64::aiohttp-3.7.4.post0-py37h5e8e339_0
#   astor              conda-forge/noarch::astor-0.8.1-pyh9f0ad1d_0
#   astunparse         conda-forge/noarch::astunparse-1.6.3-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-3.0.1-py_1000
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   cachetools         conda-forge/noarch::cachetools-4.2.2-pyhd8ed1ab_0
#   click              conda-forge/linux-64::click-8.0.1-py37h89c1867_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_1
#   flatbuffers        conda-forge/linux-64::flatbuffers-2.0.0-h9c3ff4c_0
#   gast               conda-forge/noarch::gast-0.4.0-pyh9f0ad1d_0
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   google-auth        conda-forge/noarch::google-auth-1.32.1-pyh6c4a22f_0
#   google-auth-oauth~ conda-forge/noarch::google-auth-oauthlib-0.4.1-py_2
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   grpcio             conda-forge/linux-64::grpcio-1.38.1-py37hb27c1af_0
#   h5py               conda-forge/linux-64::h5py-3.3.0-nompi_py37ha3df211_100
#   hdf5               conda-forge/linux-64::hdf5-1.10.6-nompi_h6a2412b_1114
#   icu                conda-forge/linux-64::icu-68.1-h58526e2_0
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   keras-preprocessi~ conda-forge/noarch::keras-preprocessing-1.1.2-pyhd8ed1ab_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-9_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-9_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-9.3.0-hff62375_19
#   libgfortran5       conda-forge/linux-64::libgfortran5-9.3.0-hff62375_19
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-9_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.15-pthreads_h8fe5266_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.14.0-h780b84a_0
#   markdown           conda-forge/noarch::markdown-3.3.4-pyhd8ed1ab_0
#   multidict          conda-forge/linux-64::multidict-5.1.0-py37h5e8e339_1
#   numpy              conda-forge/linux-64::numpy-1.21.0-py37h038b26d_0
#   opt_einsum         conda-forge/noarch::opt_einsum-3.3.0-pyhd8ed1ab_1
#   protobuf           pkgs/main/linux-64::protobuf-3.14.0-py37h2531618_1
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   python-flatbuffers pkgs/main/noarch::python-flatbuffers-1.12-pyhd3eb1b0_0
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   requests-oauthlib  conda-forge/noarch::requests-oauthlib-1.3.0-pyh9f0ad1d_0
#   rsa                conda-forge/noarch::rsa-4.7.2-pyh44b312d_0
#   scipy              conda-forge/linux-64::scipy-1.7.0-py37h29e03ee_0
#   snappy             conda-forge/linux-64::snappy-1.1.8-he1b5a44_3
#   tensorboard        conda-forge/noarch::tensorboard-2.5.0-pyhd8ed1ab_0
#   tensorboard-data-~ conda-forge/linux-64::tensorboard-data-server-0.6.0-py37h7f0c10b_0
#   tensorboard-plugi~ conda-forge/noarch::tensorboard-plugin-wit-1.8.0-pyh44b312d_0
#   tensorflow         pkgs/main/linux-64::tensorflow-2.5.0-mkl_py37h3e8b3f4_0
#   tensorflow-base    pkgs/main/linux-64::tensorflow-base-2.5.0-mkl_py37h35b2a3d_0
#   tensorflow-estima~ conda-forge/noarch::tensorflow-estimator-2.5.0-pyh81a9013_1
#   termcolor          conda-forge/noarch::termcolor-1.1.0-py_2
#   typing-extensions  conda-forge/noarch::typing-extensions-3.10.0.0-hd8ed1ab_0
#   werkzeug           conda-forge/noarch::werkzeug-2.0.1-pyhd8ed1ab_0
#   wrapt              conda-forge/linux-64::wrapt-1.12.1-py37h5e8e339_3
#   yarl               conda-forge/linux-64::yarl-1.6.3-py37h5e8e339_2
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.5-ha878542_0 --> 2021.5.30-ha878542_0
#   certifi                          2020.12.5-py37h89c1867_1 --> 2021.5.30-py37h89c1867_0
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1k-h7f98852_0
#   sqlite              conda-forge::sqlite-3.34.0-h74cdb3f_0 --> pkgs/main::sqlite-3.36.0-hc218d9a_0
#   typing_extensions                            3.7.4.3-py_0 --> 3.10.0.0-pyha770c72_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   wheel              conda-forge/noarch::wheel-0.36.2-pyhd~ --> conda-forge/linux-64::wheel-0.34.2-py37_0
#
#
#
# Downloading and Extracting Packages
# click-8.0.1          | 145 KB    | ##################################### | 100%
# werkzeug-2.0.1       | 219 KB    | ##################################### | 100%
# openssl-1.1.1k       | 2.1 MB    | ##################################### | 100%
# tensorflow-base-2.5. | 76.6 MB   | ##################################### | 100%
# cachetools-4.2.2     | 12 KB     | ##################################### | 100%
# gast-0.4.0           | 12 KB     | ##################################### | 100%
# async-timeout-3.0.1  | 11 KB     | ##################################### | 100%
# absl-py-0.13.0       | 97 KB     | ##################################### | 100%
# pyu2f-0.1.5          | 31 KB     | ##################################### | 100%
# multidict-5.1.0      | 67 KB     | ##################################### | 100%
# abseil-cpp-20200923. | 919 KB    | ##################################### | 100%
# libblas-3.9.0        | 11 KB     | ##################################### | 100%
# libgfortran5-9.3.0   | 2.0 MB    | ##################################### | 100%
# numpy-1.21.0         | 6.1 MB    | ##################################### | 100%
# opt_einsum-3.3.0     | 53 KB     | ##################################### | 100%
# termcolor-1.1.0      | 6 KB      | ##################################### | 100%
# libprotobuf-3.14.0   | 2.5 MB    | ##################################### | 100%
# astunparse-1.6.3     | 15 KB     | ##################################### | 100%
# snappy-1.1.8         | 32 KB     | ##################################### | 100%
# tensorboard-plugin-w | 670 KB    | ##################################### | 100%
# dataclasses-0.8      | 7 KB      | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# typing-extensions-3. | 8 KB      | ##################################### | 100%
# python-flatbuffers-1 | 24 KB     | ##################################### | 100%
# typing_extensions-3. | 28 KB     | ##################################### | 100%
# hdf5-1.10.6          | 3.1 MB    | ##################################### | 100%
# sqlite-3.36.0        | 990 KB    | ##################################### | 100%
# protobuf-3.14.0      | 303 KB    | ##################################### | 100%
# tensorflow-2.5.0     | 4 KB      | ##################################### | 100%
# requests-oauthlib-1. | 21 KB     | ##################################### | 100%
# google-pasta-0.2.0   | 42 KB     | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# pyasn1-modules-0.2.7 | 60 KB     | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# wheel-0.34.2         | 43 KB     | ##################################### | 100%
# grpcio-1.38.1        | 2.2 MB    | ##################################### | 100%
# google-auth-oauthlib | 18 KB     | ##################################### | 100%
# cached_property-1.5. | 11 KB     | ##################################### | 100%
# giflib-5.2.1         | 77 KB     | ##################################### | 100%
# pyasn1-0.4.8         | 53 KB     | ##################################### | 100%
# rsa-4.7.2            | 28 KB     | ##################################### | 100%
# yarl-1.6.3           | 142 KB    | ##################################### | 100%
# flatbuffers-2.0.0    | 1.3 MB    | ##################################### | 100%
# astor-0.8.1          | 25 KB     | ##################################### | 100%
# certifi-2021.5.30    | 141 KB    | ##################################### | 100%
# tensorboard-data-ser | 3.2 MB    | ##################################### | 100%
# markdown-3.3.4       | 67 KB     | ##################################### | 100%
# google-auth-1.32.1   | 78 KB     | ##################################### | 100%
# tensorboard-2.5.0    | 5.5 MB    | ##################################### | 100%
# ca-certificates-2021 | 136 KB    | ##################################### | 100%
# libopenblas-0.3.15   | 9.2 MB    | ##################################### | 100%
# wrapt-1.12.1         | 47 KB     | ##################################### | 100%
# aiohttp-3.7.4.post0  | 625 KB    | ##################################### | 100%
# h5py-3.3.0           | 1.3 MB    | ##################################### | 100%
# keras-preprocessing- | 34 KB     | ##################################### | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ##################################### | 100%
# cached-property-1.5. | 4 KB      | ##################################### | 100%
# tensorflow-estimator | 289 KB    | ##################################### | 100%
# scipy-1.7.0          | 21.7 MB   | ##################################### | 100%
# jpeg-9d              | 264 KB    | ##################################### | 100%
# _tflow_select-2.3.0  | 2 KB      | ##################################### | 100%
# icu-68.1             | 13.0 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install keras
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     keras-2.4.3                |     pyhd8ed1ab_0          30 KB  conda-forge
#     pyyaml-5.4.1               |   py37h5e8e339_0         189 KB  conda-forge
#     yaml-0.2.5                 |       h516909a_0          82 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         302 KB
#
# The following NEW packages will be INSTALLED:
#
#   keras              conda-forge/noarch::keras-2.4.3-pyhd8ed1ab_0
#   pyyaml             conda-forge/linux-64::pyyaml-5.4.1-py37h5e8e339_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h516909a_0
#
#
#
# Downloading and Extracting Packages
# yaml-0.2.5           | 82 KB     | ##################################### | 100%
# pyyaml-5.4.1         | 189 KB    | ##################################### | 100%
# keras-2.4.3          | 30 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
 conda install scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.0.1               |     pyhd8ed1ab_0         206 KB  conda-forge
#     scikit-learn-0.24.2        |   py37h18a542f_0         7.5 MB  conda-forge
#     threadpoolctl-2.2.0        |     pyh8a188c0_0          16 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         7.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             conda-forge/noarch::joblib-1.0.1-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-0.24.2-py37h18a542f_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-2.2.0-pyh8a188c0_0
#
#
#
# Downloading and Extracting Packages
# scikit-learn-0.24.2  | 7.5 MB    | ##################################### | 100%
# threadpoolctl-2.2.0  | 16 KB     | ##################################### | 100%
# joblib-1.0.1         | 206 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.7/site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.21.0)
# Requirement already satisfied: joblib>=0.11 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.7.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->sklearn) (2.2.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=fbb3c305de89c30c2ba8c16c44c7fbf1f753fc1d56067e70f85b27c37318a74a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

model=Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_absolute_error', optimizer='adam')



monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, 
        verbose=1, mode='auto', restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor], verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 2/2 - 1s - loss: 0.4803 - val_loss: 0.4221
# Epoch 2/1000
# 2/2 - 0s - loss: 0.4275 - val_loss: 0.3781
# Epoch 3/1000
# 2/2 - 0s - loss: 0.3751 - val_loss: 0.3332
# Epoch 4/1000
# 2/2 - 1s - loss: 0.3227 - val_loss: 0.2874
# Epoch 5/1000
# 2/2 - 0s - loss: 0.2803 - val_loss: 0.2518
# Epoch 6/1000
# 2/2 - 0s - loss: 0.2458 - val_loss: 0.2221
# Epoch 7/1000
# 2/2 - 0s - loss: 0.2168 - val_loss: 0.2041
# Epoch 8/1000
# 2/2 - 0s - loss: 0.1908 - val_loss: 0.1870
# Epoch 9/1000
# 2/2 - 1s - loss: 0.1797 - val_loss: 0.1717
# Epoch 10/1000
# 2/2 - 0s - loss: 0.1682 - val_loss: 0.1644
# Epoch 11/1000
# 2/2 - 0s - loss: 0.1586 - val_loss: 0.1605
# Epoch 12/1000
# 2/2 - 1s - loss: 0.1555 - val_loss: 0.1607
# Epoch 13/1000
# 2/2 - 0s - loss: 0.1492 - val_loss: 0.1572
# Epoch 14/1000
# 2/2 - 1s - loss: 0.1392 - val_loss: 0.1526
# Epoch 15/1000
# 2/2 - 0s - loss: 0.1297 - val_loss: 0.1470
# Epoch 16/1000
# 2/2 - 0s - loss: 0.1196 - val_loss: 0.1391
# Epoch 17/1000
# 2/2 - 0s - loss: 0.1086 - val_loss: 0.1333
# Epoch 18/1000
# 2/2 - 1s - loss: 0.1031 - val_loss: 0.1298
# Epoch 19/1000
# 2/2 - 0s - loss: 0.0993 - val_loss: 0.1269
# Epoch 20/1000
# 2/2 - 0s - loss: 0.0959 - val_loss: 0.1249
# Epoch 21/1000
# 2/2 - 0s - loss: 0.0927 - val_loss: 0.1237
# Epoch 22/1000
# 2/2 - 0s - loss: 0.0897 - val_loss: 0.1232
# Epoch 23/1000
# 2/2 - 0s - loss: 0.0893 - val_loss: 0.1249
# Epoch 24/1000
# 2/2 - 0s - loss: 0.0876 - val_loss: 0.1246
# Epoch 25/1000
# 2/2 - 0s - loss: 0.0858 - val_loss: 0.1222
# Epoch 26/1000
# 2/2 - 1s - loss: 0.0836 - val_loss: 0.1191
# Epoch 27/1000
# 2/2 - 0s - loss: 0.0818 - val_loss: 0.1173
# Epoch 28/1000
# 2/2 - 0s - loss: 0.0795 - val_loss: 0.1165
# Epoch 29/1000
# 2/2 - 1s - loss: 0.0775 - val_loss: 0.1161
# Epoch 30/1000
# 2/2 - 0s - loss: 0.0757 - val_loss: 0.1152
# Epoch 31/1000
# 2/2 - 0s - loss: 0.0740 - val_loss: 0.1140
# Epoch 32/1000
# 2/2 - 0s - loss: 0.0715 - val_loss: 0.1137
# Epoch 33/1000
# 2/2 - 0s - loss: 0.0687 - val_loss: 0.1145
# Epoch 34/1000
# 2/2 - 0s - loss: 0.0665 - val_loss: 0.1165
# Epoch 35/1000
# 2/2 - 0s - loss: 0.0644 - val_loss: 0.1184
# Epoch 36/1000
# 2/2 - 0s - loss: 0.0629 - val_loss: 0.1182
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping

# %%
pred = model.predict(x)

# %%
score = np.sqrt(metrics.mean_absolute_error(pred,y))
print(f"Final score (RMSE): {score}")
# Out:
# Final score (RMSE): 0.28695489067838237

# %%
df=pd.read_csv("80_Val.csv",sep=",")
x_columns=df.columns
x_test = df[x_columns].values
y_test = df['RF'].values

# %%
model=Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_absolute_error', optimizer='adam')
model.fit(x_test, y_test, epochs= 52, batch_size=1,verbose=2)
# Out:
# Epoch 1/52
# 20/20 - 1s - loss: 0.7633
# Epoch 2/52
# 20/20 - 1s - loss: 0.3946
# Epoch 3/52
# 20/20 - 0s - loss: 0.2521
# Epoch 4/52
# 20/20 - 0s - loss: 0.1698
# Epoch 5/52
# 20/20 - 1s - loss: 0.1156
# Epoch 6/52
# 20/20 - 1s - loss: 0.0599
# Epoch 7/52
# 20/20 - 0s - loss: 0.0455
# Epoch 8/52
# 20/20 - 0s - loss: 0.0452
# Epoch 9/52
# 20/20 - 0s - loss: 0.0510
# Epoch 10/52
# 20/20 - 0s - loss: 0.0495
# Epoch 11/52
# 20/20 - 0s - loss: 0.0462
# Epoch 12/52
# 20/20 - 1s - loss: 0.0423
# Epoch 13/52
# 20/20 - 1s - loss: 0.0309
# Epoch 14/52
# 20/20 - 0s - loss: 0.0284
# Epoch 15/52
# 20/20 - 0s - loss: 0.0456
# Epoch 16/52
# 20/20 - 0s - loss: 0.0303
# Epoch 17/52
# 20/20 - 0s - loss: 0.0265
# Epoch 18/52
# 20/20 - 1s - loss: 0.0287
# Epoch 19/52
# 20/20 - 0s - loss: 0.0384
# Epoch 20/52
# 20/20 - 0s - loss: 0.0337
# Epoch 21/52
# 20/20 - 0s - loss: 0.0282
# Epoch 22/52
# 20/20 - 0s - loss: 0.0318
# Epoch 23/52
# 20/20 - 0s - loss: 0.0299
# Epoch 24/52
# 20/20 - 1s - loss: 0.0350
# Epoch 25/52
# 20/20 - 0s - loss: 0.0275
# Epoch 26/52
# 20/20 - 0s - loss: 0.0304
# Epoch 27/52
# 20/20 - 0s - loss: 0.0226
# Epoch 28/52
# 20/20 - 0s - loss: 0.0204
# Epoch 29/52
# 20/20 - 1s - loss: 0.0259
# Epoch 30/52
# 20/20 - 0s - loss: 0.0215
# Epoch 31/52
# 20/20 - 0s - loss: 0.0247
# Epoch 32/52
# 20/20 - 0s - loss: 0.0230
# Epoch 33/52
# 20/20 - 1s - loss: 0.0198
# Epoch 34/52
# 20/20 - 1s - loss: 0.0215
# Epoch 35/52
# 20/20 - 0s - loss: 0.0252
# Epoch 36/52
# 20/20 - 1s - loss: 0.0320
# Epoch 37/52
# 20/20 - 1s - loss: 0.0273
# Epoch 38/52
# 20/20 - 1s - loss: 0.0265
# Epoch 39/52
# 20/20 - 1s - loss: 0.0253
# Epoch 40/52
# 20/20 - 1s - loss: 0.0234
# Epoch 41/52
# 20/20 - 1s - loss: 0.0257
# Epoch 42/52
# 20/20 - 1s - loss: 0.0294
# Epoch 43/52
# 20/20 - 0s - loss: 0.0258
# Epoch 44/52
# 20/20 - 1s - loss: 0.0252
# Epoch 45/52
# 20/20 - 1s - loss: 0.0248
# Epoch 46/52
# 20/20 - 2s - loss: 0.0247
# Epoch 47/52
# 20/20 - 1s - loss: 0.0195
# Epoch 48/52
# 20/20 - 2s - loss: 0.0214
# Epoch 49/52
# 20/20 - 1s - loss: 0.0195
# Epoch 50/52
# 20/20 - 1s - loss: 0.0229
# Epoch 51/52
# 20/20 - 0s - loss: 0.0186
# Epoch 52/52
# 20/20 - 0s - loss: 0.0275
