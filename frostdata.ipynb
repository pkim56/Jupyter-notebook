# 18  0.186567  0.612274   0.418251  ...  0.242499  0.160000      0.866667
# 19  0.231343  0.362195   0.341255  ...  0.346075  0.304000      0.200000
#
#     CATS2D_01_LL  SM1_Dz(v)      SIC0  SM1_Dz(Z)    SIC0.1  SM1_Dz(Z).1  \
# 0       0.142857   0.725041  0.535826   0.229188  0.535826     0.229188
# 1       0.571429   1.000000  0.065421   0.000000  0.065421     0.000000
# 2       0.714286   1.000000  0.037383   0.000000  0.037383     0.000000
# 3       1.000000   1.000000  0.000000   0.000000  0.000000     0.000000
# 4       0.142857   0.355974  0.311526   0.575540  0.311526     0.575540
# 5       0.285714   0.773322  0.183801   0.137718  0.183801     0.137718
# 6       0.142857   0.355974  0.221184   0.575540  0.221184     0.575540
# 7       0.142857   0.519640  0.358255   0.416238  0.358255     0.416238
# 8       0.000000   0.519640  0.778816   0.416238  0.778816     0.416238
# 9       0.000000   0.355974  0.647975   0.575540  0.647975     0.575540
# 10      0.071429   0.725041  0.535826   0.229188  0.535826     0.229188
# 11      0.428571   0.355974  0.654206   0.575540  0.654206     0.575540
# 12      0.071429   0.355974  0.470405   0.575540  0.470405     0.575540
# 13      0.142857   0.519640  0.308411   0.416238  0.308411     0.416238
# 14      0.000000   0.355974  0.775701   0.575540  0.775701     0.575540
# 15      0.000000   0.519640  0.426791   0.416238  0.426791     0.416238
# 16      0.000000   0.219313  0.342679   0.712230  0.342679     0.712230
# 17      0.428571   0.355974  0.221184   0.575540  0.221184     0.575540
# 18      0.857143   0.519640  0.208723   0.416238  0.208723     0.416238
# 19      0.142857   0.386252  0.348910   0.509764  0.348910     0.509764
#
#           RF
# 0   0.479798
# 1   0.949495
# 2   0.934343
# 3   0.939394
# 4   0.409091
# 5   0.732323
# 6   0.414141
# 7   0.454545
# 8   0.136364
# 9   0.151515
# 10  0.313131
# 11  0.106061
# 12  0.318182
# 13  0.454545
# 14  0.171717
# 15  0.500000
# 16  0.262626
# 17  0.535354
# 18  0.671717
# 19  0.429293
#
# [20 rows x 22 columns]

# %%
import numpy as np
train_data=np.array(train_data)

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
val_data -= mean
val_data /= std

# %%
from keras import models
from keras import layers
def build_model():
   model = models.Sequential()
   model.add(layers.Dense(32, activation='relu', #first hidden layer
   input_shape=(train_data.shape[1],)))
   model.add(layers.Dense(32, activation='relu', #second hidden layer
   input_shape=(train_data.shape[1],)))
   model.add(layers.Dense(64, activation='relu'))  #third hidden layer
   model.add(layers.Dense(1))  #output is single unit and we have no activation because we are perdicting a regression value
   model.compile(optimizer='rmsprop', loss='mse', metrics=['mae']) #mse is the loss function for this problem and mae is the new way to moonitor loss
   return model

# %%
import numpy as np
k=4
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# AttributeError: 'function' object has no attribute 'summary'

# %%
num_epochs = 500
all_mae_histories = []
for i in range(k):
   print('processing fold #', i)
   val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
   
   partial_train_data = np.concatenate(
   [train_data[:i * num_val_samples],
   train_data[(i + 1) * num_val_samples:]],
   axis=0) 
   
   model = build_model()
   history = model.fit(partial_train_data)
   validation_data=(val_data, val_targets),
   epochs=num_epochs, batch_size=12)
   mae_history = history.history['val_mean_absolute_error']
   all_mae_histories.append(mae_history)
# Out:
#   File "<ipython-input-40-44e7f4152b4f>", line 15
#     epochs=num_epochs, batch_size=12)
#                                     ^
# SyntaxError: invalid syntax
