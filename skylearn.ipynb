# %%
# !pip install pandas

import pandas as pd
df=pd.read_csv("80_Train.csv",sep=",")
# Out:
# Collecting pandas
#   Downloading pandas-1.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 7.2 MB/s eta 0:00:01    |██████████████████▋             | 6.7 MB 9.0 MB/s eta 0:00:01
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 4.6 MB/s eta 0:00:011     |██████████████████████████████▊ | 15.1 MB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.21.1 pandas-1.3.1

# %%
x_columns=df.columns
x = df[x_columns].values
y = df['RF'].values

# %%
import tensorflow as tf

# %%
conda install keras
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: \
# Note: you may need to restart the kernel to use updated packages.

# %%
 conda install scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     certifi-2021.5.30          |   py37h89c1867_0         141 KB  conda-forge
#     joblib-1.0.1               |     pyhd8ed1ab_0         206 KB  conda-forge
#     libblas-3.9.0              |      10_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |      10_openblas          11 KB  conda-forge
#     libgfortran-ng-9.3.0       |      hff62375_19          22 KB  conda-forge
#     libgfortran5-9.3.0         |      hff62375_19         2.0 MB  conda-forge
#     liblapack-3.9.0            |      10_openblas          11 KB  conda-forge
#     libopenblas-0.3.17         |pthreads_h8fe5266_1         9.2 MB  conda-forge
#     numpy-1.21.1               |   py37h038b26d_0         6.1 MB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     scikit-learn-0.24.2        |   py37h18a542f_0         7.5 MB  conda-forge
#     scipy-1.7.0                |   py37h29e03ee_1        21.7 MB  conda-forge
#     threadpoolctl-2.2.0        |     pyh8a188c0_0          16 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        49.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             conda-forge/noarch::joblib-1.0.1-pyhd8ed1ab_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-10_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-10_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-9.3.0-hff62375_19
#   libgfortran5       conda-forge/linux-64::libgfortran5-9.3.0-hff62375_19
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-10_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.17-pthreads_h8fe5266_1
#   numpy              conda-forge/linux-64::numpy-1.21.1-py37h038b26d_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-0.24.2-py37h18a542f_0
#   scipy              conda-forge/linux-64::scipy-1.7.0-py37h29e03ee_1
#   threadpoolctl      conda-forge/noarch::threadpoolctl-2.2.0-pyh8a188c0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.5-ha878542_0 --> 2021.5.30-ha878542_0
#   certifi                          2020.12.5-py37h89c1867_1 --> 2021.5.30-py37h89c1867_0
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1k-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# libblas-3.9.0        | 11 KB     | ##################################### | 100%
# libgfortran5-9.3.0   | 2.0 MB    | ##################################### | 100%
# numpy-1.21.1         | 6.1 MB    | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# joblib-1.0.1         | 206 KB    | ##################################### | 100%
# scikit-learn-0.24.2  | 7.5 MB    | ##################################### | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# threadpoolctl-2.2.0  | 16 KB     | ##################################### | 100%
# certifi-2021.5.30    | 141 KB    | ##################################### | 100%
# ca-certificates-2021 | 136 KB    | ##################################### | 100%
# scipy-1.7.0          | 21.7 MB   | ##################################### | 100%
# openssl-1.1.1k       | 2.1 MB    | ##################################### | 100%
# libopenblas-0.3.17   | 9.2 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping


kf = KFold(5, shuffle=True, random_state=42) # Use for KFold classification
    
out_of_sample_y = []
out_of_sample_pred = []
fold = 0
for train, test in kf.split(x):
    fold+=1
    print(f"Fold #{fold}")
        
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]
    
    model = Sequential()
    model.add(Dense(64, input_dim=x.shape[1], activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_absolute_error', optimizer='adam')
    
  
    model.fit(x_train,y_train,validation_data=(x_test,y_test),verbose=2,
              epochs=30)
    
    pred = model.predict(x_test)
    
    out_of_sample_y.append(y_test)
    out_of_sample_pred.append(pred)    

    # Measure this fold's RMSE
    score = np.sqrt(metrics.mean_absolute_error(pred,y_test))
    print(f"Fold score (MAE): {score}")
# Build the oos prediction list and calculate the error.
out_of_sample_y = np.concatenate(out_of_sample_y)
out_of_sample_pred = np.concatenate(out_of_sample_pred)




score = np.sqrt(metrics.mean_absolute_error(out_of_sample_pred,out_of_sample_y))
print(f"Final, out of sample score (RMSE): {score}")
# Out:
# Fold #1
# Train on 48 samples, validate on 12 samples
# Epoch 1/30
# 48/48 - 1s - loss: 0.4447 - val_loss: 0.3717
# Epoch 2/30
# 48/48 - 0s - loss: 0.4190 - val_loss: 0.2568
# Epoch 3/30
# 48/48 - 0s - loss: 0.3515 - val_loss: 0.2121
# Epoch 4/30
# 48/48 - 0s - loss: 0.3225 - val_loss: 0.2325
# Epoch 5/30
# 48/48 - 0s - loss: 0.3007 - val_loss: 0.2547
# Epoch 6/30
# 48/48 - 0s - loss: 0.2732 - val_loss: 0.2419
# Epoch 7/30
# 48/48 - 0s - loss: 0.2925 - val_loss: 0.2054
# Epoch 8/30
# 48/48 - 0s - loss: 0.2557 - val_loss: 0.1687
# Epoch 9/30
# 48/48 - 0s - loss: 0.2487 - val_loss: 0.1511
# Epoch 10/30
# 48/48 - 0s - loss: 0.2443 - val_loss: 0.1821
# Epoch 11/30
# 48/48 - 0s - loss: 0.2411 - val_loss: 0.1978
# Epoch 12/30
# 48/48 - 0s - loss: 0.2040 - val_loss: 0.1961
# Epoch 13/30
# 48/48 - 0s - loss: 0.2115 - val_loss: 0.1836
# Epoch 14/30
# 48/48 - 0s - loss: 0.1885 - val_loss: 0.1578
# Epoch 15/30
# 48/48 - 0s - loss: 0.1847 - val_loss: 0.1326
# Epoch 16/30
# 48/48 - 0s - loss: 0.1979 - val_loss: 0.1095
# Epoch 17/30
# 48/48 - 0s - loss: 0.1676 - val_loss: 0.1062
# Epoch 18/30
# 48/48 - 0s - loss: 0.1822 - val_loss: 0.1057
# Epoch 19/30
# 48/48 - 0s - loss: 0.1458 - val_loss: 0.1072
# Epoch 20/30
# 48/48 - 0s - loss: 0.1806 - val_loss: 0.1076
# Epoch 21/30
# 48/48 - 0s - loss: 0.1599 - val_loss: 0.1084
# Epoch 22/30
# 48/48 - 0s - loss: 0.1314 - val_loss: 0.1116
# Epoch 23/30
# 48/48 - 0s - loss: 0.1567 - val_loss: 0.1171
# Epoch 24/30
# 48/48 - 0s - loss: 0.1302 - val_loss: 0.1218
# Epoch 25/30
# 48/48 - 0s - loss: 0.1502 - val_loss: 0.1275
# Epoch 26/30
# 48/48 - 0s - loss: 0.1308 - val_loss: 0.1348
# Epoch 27/30
# 48/48 - 0s - loss: 0.1434 - val_loss: 0.1295
# Epoch 28/30
# 48/48 - 0s - loss: 0.1335 - val_loss: 0.1190
# Epoch 29/30
# 48/48 - 0s - loss: 0.1138 - val_loss: 0.1041
# Epoch 30/30
# 48/48 - 0s - loss: 0.1457 - val_loss: 0.0931
# Fold score (MAE): 0.3050488726416449
# Fold #2
# Train on 48 samples, validate on 12 samples
# Epoch 1/30
# 48/48 - 1s - loss: 0.3695 - val_loss: 0.2329
# Epoch 2/30
# 48/48 - 0s - loss: 0.2696 - val_loss: 0.1927
# Epoch 3/30
# 48/48 - 0s - loss: 0.2355 - val_loss: 0.1715
# Epoch 4/30
# 48/48 - 0s - loss: 0.2114 - val_loss: 0.1528
# Epoch 5/30
# 48/48 - 0s - loss: 0.2100 - val_loss: 0.1308
# Epoch 6/30
# 48/48 - 0s - loss: 0.2039 - val_loss: 0.1042
# Epoch 7/30
# 48/48 - 0s - loss: 0.1833 - val_loss: 0.0801
# Epoch 8/30
# 48/48 - 0s - loss: 0.1553 - val_loss: 0.0658
# Epoch 9/30
# 48/48 - 0s - loss: 0.1568 - val_loss: 0.0672
# Epoch 10/30
# 48/48 - 0s - loss: 0.1292 - val_loss: 0.0709
# Epoch 11/30
# 48/48 - 0s - loss: 0.1663 - val_loss: 0.0814
# Epoch 12/30
# 48/48 - 0s - loss: 0.1668 - val_loss: 0.0906
# Epoch 13/30
# 48/48 - 0s - loss: 0.1615 - val_loss: 0.0952
# Epoch 14/30
# 48/48 - 0s - loss: 0.1378 - val_loss: 0.0962
# Epoch 15/30
# 48/48 - 0s - loss: 0.1208 - val_loss: 0.0927
# Epoch 16/30
# 48/48 - 0s - loss: 0.1507 - val_loss: 0.0858
# Epoch 17/30
# 48/48 - 0s - loss: 0.1408 - val_loss: 0.0790
# Epoch 18/30
# 48/48 - 0s - loss: 0.1315 - val_loss: 0.0790
# Epoch 19/30
# 48/48 - 0s - loss: 0.1354 - val_loss: 0.0781
# Epoch 20/30
# 48/48 - 0s - loss: 0.1237 - val_loss: 0.0741
# Epoch 21/30
# 48/48 - 0s - loss: 0.1310 - val_loss: 0.0712
# Epoch 22/30
# 48/48 - 0s - loss: 0.1076 - val_loss: 0.0665
# Epoch 23/30
# 48/48 - 0s - loss: 0.1182 - val_loss: 0.0610
# Epoch 24/30
# 48/48 - 0s - loss: 0.1397 - val_loss: 0.0573
# Epoch 25/30
# 48/48 - 0s - loss: 0.1164 - val_loss: 0.0545
# Epoch 26/30
# 48/48 - 0s - loss: 0.1217 - val_loss: 0.0538
# Epoch 27/30
# 48/48 - 0s - loss: 0.1016 - val_loss: 0.0529
# Epoch 28/30
# 48/48 - 0s - loss: 0.1211 - val_loss: 0.0517
# Epoch 29/30
# 48/48 - 0s - loss: 0.0944 - val_loss: 0.0543
# Epoch 30/30
# 48/48 - 0s - loss: 0.0947 - val_loss: 0.0569
# Fold score (MAE): 0.2386314097962552
# Fold #3
# Train on 48 samples, validate on 12 samples
# Epoch 1/30
# 48/48 - 1s - loss: 0.4276 - val_loss: 0.3281
# Epoch 2/30
# 48/48 - 0s - loss: 0.3285 - val_loss: 0.3072
# Epoch 3/30
# 48/48 - 0s - loss: 0.2724 - val_loss: 0.3062
# Epoch 4/30
# 48/48 - 0s - loss: 0.2231 - val_loss: 0.2975
# Epoch 5/30
# 48/48 - 0s - loss: 0.2287 - val_loss: 0.2807
# Epoch 6/30
# 48/48 - 0s - loss: 0.1925 - val_loss: 0.2628
# Epoch 7/30
# 48/48 - 0s - loss: 0.1970 - val_loss: 0.2437
# Epoch 8/30
# 48/48 - 0s - loss: 0.2067 - val_loss: 0.2113
# Epoch 9/30
# 48/48 - 0s - loss: 0.1821 - val_loss: 0.1753
# Epoch 10/30
# 48/48 - 0s - loss: 0.1287 - val_loss: 0.1425
# Epoch 11/30
# 48/48 - 0s - loss: 0.1316 - val_loss: 0.1148
# Epoch 12/30
# 48/48 - 0s - loss: 0.1576 - val_loss: 0.0998
# Epoch 13/30
# 48/48 - 0s - loss: 0.1467 - val_loss: 0.0828
# Epoch 14/30
# 48/48 - 0s - loss: 0.1147 - val_loss: 0.0711
# Epoch 15/30
# 48/48 - 0s - loss: 0.1237 - val_loss: 0.0654
# Epoch 16/30
# 48/48 - 0s - loss: 0.0996 - val_loss: 0.0672
# Epoch 17/30
# 48/48 - 0s - loss: 0.1245 - val_loss: 0.0705
# Epoch 18/30
# 48/48 - 0s - loss: 0.1143 - val_loss: 0.0669
# Epoch 19/30
# 48/48 - 0s - loss: 0.1131 - val_loss: 0.0614
# Epoch 20/30
# 48/48 - 0s - loss: 0.1162 - val_loss: 0.0556
# Epoch 21/30
# 48/48 - 0s - loss: 0.1115 - val_loss: 0.0575
# Epoch 22/30
# 48/48 - 0s - loss: 0.1224 - val_loss: 0.0604
# Epoch 23/30
# 48/48 - 0s - loss: 0.1279 - val_loss: 0.0595
# Epoch 24/30
# 48/48 - 0s - loss: 0.1337 - val_loss: 0.0549
# Epoch 25/30
# 48/48 - 0s - loss: 0.1005 - val_loss: 0.0534
# Epoch 26/30
# 48/48 - 0s - loss: 0.1207 - val_loss: 0.0535
# Epoch 27/30
# 48/48 - 0s - loss: 0.1105 - val_loss: 0.0580
# Epoch 28/30
# 48/48 - 0s - loss: 0.1090 - val_loss: 0.0628
# Epoch 29/30
# 48/48 - 0s - loss: 0.1189 - val_loss: 0.0642
# Epoch 30/30
# 48/48 - 0s - loss: 0.1111 - val_loss: 0.0664
# Fold score (MAE): 0.257674996602109
# Fold #4
# Train on 48 samples, validate on 12 samples
# Epoch 1/30
# 48/48 - 1s - loss: 0.2937 - val_loss: 0.1750
# Epoch 2/30
# 48/48 - 0s - loss: 0.2523 - val_loss: 0.1256
# Epoch 3/30
# 48/48 - 0s - loss: 0.1835 - val_loss: 0.0957
# Epoch 4/30
# 48/48 - 0s - loss: 0.1911 - val_loss: 0.0995
# Epoch 5/30
# 48/48 - 0s - loss: 0.1765 - val_loss: 0.1028
# Epoch 6/30
# 48/48 - 0s - loss: 0.2048 - val_loss: 0.0960
# Epoch 7/30
# 48/48 - 0s - loss: 0.1661 - val_loss: 0.0863
# Epoch 8/30
# 48/48 - 0s - loss: 0.1470 - val_loss: 0.0924
# Epoch 9/30
# 48/48 - 0s - loss: 0.1672 - val_loss: 0.1143
# Epoch 10/30
# 48/48 - 0s - loss: 0.1321 - val_loss: 0.1323
# Epoch 11/30
# 48/48 - 0s - loss: 0.1285 - val_loss: 0.1430
# Epoch 12/30
# 48/48 - 0s - loss: 0.1612 - val_loss: 0.1466
# Epoch 13/30
# 48/48 - 0s - loss: 0.1654 - val_loss: 0.1356
# Epoch 14/30
# 48/48 - 0s - loss: 0.1476 - val_loss: 0.1207
# Epoch 15/30
# 48/48 - 0s - loss: 0.1098 - val_loss: 0.1064
# Epoch 16/30
# 48/48 - 0s - loss: 0.1181 - val_loss: 0.0930
# Epoch 17/30
# 48/48 - 0s - loss: 0.1271 - val_loss: 0.0886
# Epoch 18/30
# 48/48 - 0s - loss: 0.1161 - val_loss: 0.0924
# Epoch 19/30
# 48/48 - 0s - loss: 0.1229 - val_loss: 0.0978
# Epoch 20/30
# 48/48 - 0s - loss: 0.1271 - val_loss: 0.1012
# Epoch 21/30
# 48/48 - 0s - loss: 0.1002 - val_loss: 0.1009
# Epoch 22/30
# 48/48 - 0s - loss: 0.0908 - val_loss: 0.0978
# Epoch 23/30
# 48/48 - 0s - loss: 0.1226 - val_loss: 0.0937
# Epoch 24/30
# 48/48 - 0s - loss: 0.1214 - val_loss: 0.0885
# Epoch 25/30
# 48/48 - 0s - loss: 0.1259 - val_loss: 0.0832
# Epoch 26/30
# 48/48 - 0s - loss: 0.1062 - val_loss: 0.0793
# Epoch 27/30
# 48/48 - 0s - loss: 0.1110 - val_loss: 0.0758
# Epoch 28/30
# 48/48 - 0s - loss: 0.1039 - val_loss: 0.0716
# Epoch 29/30
# 48/48 - 0s - loss: 0.1292 - val_loss: 0.0657
# Epoch 30/30
# 48/48 - 0s - loss: 0.0973 - val_loss: 0.0564
# Fold score (MAE): 0.23749299225319712
# Fold #5
# Train on 48 samples, validate on 12 samples
# Epoch 1/30
# 48/48 - 1s - loss: 0.3132 - val_loss: 0.3207
# Epoch 2/30
# 48/48 - 0s - loss: 0.2617 - val_loss: 0.2868
# Epoch 3/30
# 48/48 - 0s - loss: 0.2724 - val_loss: 0.2588
# Epoch 4/30
# 48/48 - 0s - loss: 0.2667 - val_loss: 0.2326
# Epoch 5/30
# 48/48 - 0s - loss: 0.2316 - val_loss: 0.2032
# Epoch 6/30
# 48/48 - 0s - loss: 0.1946 - val_loss: 0.1756
# Epoch 7/30
# 48/48 - 0s - loss: 0.2070 - val_loss: 0.1482
# Epoch 8/30
# 48/48 - 0s - loss: 0.1821 - val_loss: 0.1204
# Epoch 9/30
# 48/48 - 0s - loss: 0.1580 - val_loss: 0.0928
# Epoch 10/30
# 48/48 - 0s - loss: 0.1604 - val_loss: 0.0725
# Epoch 11/30
# 48/48 - 0s - loss: 0.1414 - val_loss: 0.0708
# Epoch 12/30
# 48/48 - 0s - loss: 0.1556 - val_loss: 0.0753
# Epoch 13/30
# 48/48 - 0s - loss: 0.1607 - val_loss: 0.0772
# Epoch 14/30
# 48/48 - 0s - loss: 0.1294 - val_loss: 0.0834
# Epoch 15/30
# 48/48 - 0s - loss: 0.1312 - val_loss: 0.0844
# Epoch 16/30
# 48/48 - 0s - loss: 0.1303 - val_loss: 0.0885
# Epoch 17/30
# 48/48 - 0s - loss: 0.1214 - val_loss: 0.0933
# Epoch 18/30
# 48/48 - 0s - loss: 0.1129 - val_loss: 0.0816
# Epoch 19/30
# 48/48 - 0s - loss: 0.1155 - val_loss: 0.0742
# Epoch 20/30
# 48/48 - 0s - loss: 0.1121 - val_loss: 0.0718
# Epoch 21/30
# 48/48 - 0s - loss: 0.1292 - val_loss: 0.0727
# Epoch 22/30
# 48/48 - 0s - loss: 0.1195 - val_loss: 0.0809
# Epoch 23/30
# 48/48 - 0s - loss: 0.1011 - val_loss: 0.0963
# Epoch 24/30
# 48/48 - 0s - loss: 0.1054 - val_loss: 0.1070
# Epoch 25/30
# 48/48 - 0s - loss: 0.1438 - val_loss: 0.1173
# Epoch 26/30
# 48/48 - 0s - loss: 0.1216 - val_loss: 0.1198
# Epoch 27/30
# 48/48 - 0s - loss: 0.1191 - val_loss: 0.1110
# Epoch 28/30
# 48/48 - 0s - loss: 0.1082 - val_loss: 0.0986
# Epoch 29/30
# 48/48 - 0s - loss: 0.1121 - val_loss: 0.0963
# Epoch 30/30
# 48/48 - 0s - loss: 0.0893 - val_loss: 0.0988
# Fold score (MAE): 0.3143824024256039
# Final, out of sample score (RMSE): 0.2726299266916437

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
resultsTest = np.genfromtxt("80_Train.csv",
 delimiter=",")
plt.plot(out_of_sample_y, #training Y value
 out_of_sample_pred, #predicted Y value
 'ro') #red dots
plt.title('Training Set')
plt.xlabel('Actual')
plt.ylabel('Predicted')

# %%
from sklearn.metrics import r2_score
testR2 = r2_score(out_of_sample_pred, out_of_sample_y)

# %%
print(testR2)
# Out:
# 0.8088123132622312
